# %%
from random import gauss
from random import seed
from matplotlib import pyplot
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# plot
pyplot.plot(data)
pyplot.show()

# %% [markdown]
# # Autocorrelation

# %%
from random import gauss
from random import seed
import numpy as np
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# square the dataset
squared_data = [x**2 for x in data]
# create acf plot
plot_acf(np.array(squared_data))
pyplot.show()

# %% [markdown]
# # ARCH Model

# %%
from random import gauss
from random import seed
from matplotlib import pyplot
from arch import arch_model
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# split into train/test
n_test = 10
train, test = data[:-n_test], data[-n_test:]
# define model
model = arch_model(train, mean='Zero', vol='ARCH', p=15)
# fit model
model_fit = model.fit()
# forecast the test set
yhat = model_fit.forecast(horizon=n_test)
# plot the actual variance
var = [i*0.01 for i in range(0,100)]
pyplot.plot(var[-n_test:])
# plot forecast variance
pyplot.plot(yhat.variance.values[-1, :])
pyplot.show()
# Out:
# Iteration:      1,   Func. Count:     18,   Neg. LLF: 41.42285909902891
# Iteration:      2,   Func. Count:     37,   Neg. LLF: 38.582360846172215
# Iteration:      3,   Func. Count:     56,   Neg. LLF: 36.708576315662114
# Iteration:      4,   Func. Count:     75,   Neg. LLF: 35.64329952104845
# Iteration:      5,   Func. Count:     94,   Neg. LLF: 34.38855063608331
# Iteration:      6,   Func. Count:    113,   Neg. LLF: 31.603116204347945
# Iteration:      7,   Func. Count:    132,   Neg. LLF: 30.180001234673853
# Iteration:      8,   Func. Count:    150,   Neg. LLF: 28.71972677708831
# Iteration:      9,   Func. Count:    169,   Neg. LLF: 25.763849161046288
# Iteration:     10,   Func. Count:    189,   Neg. LLF: 25.73244946622813
# Iteration:     11,   Func. Count:    208,   Neg. LLF: 25.64989966263733
# Iteration:     12,   Func. Count:    227,   Neg. LLF: 25.560401236872735
# Iteration:     13,   Func. Count:    247,   Neg. LLF: 25.546557128200874
# Iteration:     14,   Func. Count:    266,   Neg. LLF: 25.488553441181207
# Iteration:     15,   Func. Count:    285,   Neg. LLF: 25.484752533276154
# Iteration:     16,   Func. Count:    304,   Neg. LLF: 25.48361375401976
# Iteration:     17,   Func. Count:    323,   Neg. LLF: 25.48293017144969
# Iteration:     18,   Func. Count:    341,   Neg. LLF: 25.482149520363045
# Iteration:     19,   Func. Count:    359,   Neg. LLF: 25.480673741126
# Iteration:     20,   Func. Count:    377,   Neg. LLF: 25.478363072222887
# Iteration:     21,   Func. Count:    395,   Neg. LLF: 25.47763915183635
# Iteration:     22,   Func. Count:    413,   Neg. LLF: 25.47751047468227
# Iteration:     23,   Func. Count:    431,   Neg. LLF: 25.477507598357416
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.477507632033813
#             Iterations: 23
#             Function evaluations: 431
#             Gradient evaluations: 23
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:21: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   FutureWarning,

# %% [markdown]
# # GARCH Model

# %%
# example of ARCH model
from random import gauss
from random import seed
from matplotlib import pyplot
from arch import arch_model
# seed pseudorandom number generator
seed(1)
# create dataset
data = [gauss(0, i*0.01) for i in range(0,100)]
# split into train/test
n_test = 10
train, test = data[:-n_test], data[-n_test:]
# define model
model = arch_model(train, mean='Zero', vol='GARCH', p=15, q=15)
# fit model
model_fit = model.fit()
# forecast the test set
yhat = model_fit.forecast(horizon=n_test)
# plot the actual variance
var = [i*0.01 for i in range(0,100)]
pyplot.plot(var[-n_test:])
# plot forecast variance
pyplot.plot(yhat.variance.values[-1, :])
pyplot.show()
# Out:
# Iteration:      1,   Func. Count:     33,   Neg. LLF: 50.22157561649052
# Iteration:      2,   Func. Count:     71,   Neg. LLF: 49.70879553327738
# Iteration:      3,   Func. Count:    105,   Neg. LLF: 46.966011911959896
# Iteration:      4,   Func. Count:    139,   Neg. LLF: 43.15002481355702
# Iteration:      5,   Func. Count:    173,   Neg. LLF: 40.82899175419099
# Iteration:      6,   Func. Count:    207,   Neg. LLF: 38.9923588856261
# Iteration:      7,   Func. Count:    241,   Neg. LLF: 35.11219755986003
# Iteration:      8,   Func. Count:    275,   Neg. LLF: 30.857246785366787
# Iteration:      9,   Func. Count:    309,   Neg. LLF: 29.78736581915697
# Iteration:     10,   Func. Count:    343,   Neg. LLF: 28.25528061300631
# Iteration:     11,   Func. Count:    376,   Neg. LLF: 26.95760339635258
# Iteration:     12,   Func. Count:    411,   Neg. LLF: 26.71528760128259
# Iteration:     13,   Func. Count:    445,   Neg. LLF: 26.284968289059357
# Iteration:     14,   Func. Count:    479,   Neg. LLF: 25.97251875365633
# Iteration:     15,   Func. Count:    513,   Neg. LLF: 25.840842353282707
# Iteration:     16,   Func. Count:    547,   Neg. LLF: 25.62889255751715
# Iteration:     17,   Func. Count:    580,   Neg. LLF: 25.516088583470744
# Iteration:     18,   Func. Count:    614,   Neg. LLF: 25.499363782419824
# Iteration:     19,   Func. Count:    648,   Neg. LLF: 25.49425655478956
# Iteration:     20,   Func. Count:    681,   Neg. LLF: 25.492119571597012
# Iteration:     21,   Func. Count:    714,   Neg. LLF: 25.48542479795612
# Iteration:     22,   Func. Count:    747,   Neg. LLF: 25.479684960328083
# Iteration:     23,   Func. Count:    780,   Neg. LLF: 25.477822473419383
# Iteration:     24,   Func. Count:    813,   Neg. LLF: 25.477525653613668
# Iteration:     25,   Func. Count:    846,   Neg. LLF: 25.477511491024906
# Iteration:     26,   Func. Count:    879,   Neg. LLF: 25.477507888134582
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 25.477507925151126
#             Iterations: 26
#             Function evaluations: 879
#             Gradient evaluations: 26
# C:\ProgramData\Anaconda3\lib\site-packages\arch\__future__\_utility.py:21: FutureWarning:
# The default for reindex is True. After September 2021 this will change to
# False. Set reindex to True or False to silence this message. Alternatively,
# you can use the import comment
#
# from arch.__future__ import reindexing
#
# to globally set reindex to True and silence this warning.
#
#   FutureWarning,
